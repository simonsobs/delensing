# %%
import healpy as hp, numpy as np, prjlib, warnings
from matplotlib.pyplot import *
warnings.filterwarnings("ignore")

# %%
pobj = { t : prjlib.analysis_init(t=t,freq='145',ntype='base_roll50') for t in ['la','sa'] }

# %%
H = { t : prjlib.hitmap(t,pobj[t].nside) for t in ['la','sa'] }

# %%
for t in ['la','sa']:
    hp.mollview(H[t],min=0,max=1,title='Hitcount, '+t)
