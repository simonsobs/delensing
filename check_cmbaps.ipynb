# %%
import numpy as np, basic, prjlib, plottools as pl
from matplotlib.pyplot import *

# %%
psa, fsa, r = prjlib.analysis_init(t='sa',freq='145')
pla, fla, r = prjlib.analysis_init(t='la',freq='145')
Pla, Fla, r = prjlib.analysis_init(t='la',freq='coadd')
pid, fid, r = prjlib.analysis_init(t='id',freq='145')

# %%
l, TT0, EE0, BB0 = np.loadtxt(fsa.cmb.scl,unpack=True,usecols=(0,5,6,7))
l, TT1, EE1, BB1 = np.loadtxt(fla.cmb.scl,unpack=True,usecols=(0,5,6,7))
l, TT2, EE2, BB2 = np.loadtxt(fid.cmb.scl,unpack=True,usecols=(0,5,6,7))

# %%
# TT
pl.plot_1dstyle(xmin=2,xmax=2048,ylog=True,ymin=1e-7,ymax=3e-6)
plot(l,l**3*TT0,label='sa')
plot(l,l**3*TT1,label='la')
plot(l,l**3*TT2,label='id')
plot(l,l**3*r.lcl[0,:],label='input')
legend()

# %%
# EE + noise
l, ees, een = np.loadtxt(fla.cmb.scl,unpack=True,usecols=(0,6,10))
l, EEs, EEn = np.loadtxt(Fla.cmb.scl,unpack=True,usecols=(0,6,10))
pl.plot_1dstyle(xmin=2,xmax=8000,ylog=True,ymin=1e-2,ymax=1e5)
plot(l,l*(l+1.)*ees/2./np.pi*2.72e6**2,label='sig')
plot(l,l*(l+1.)*een/2./np.pi*2.72e6**2,label='noi (145)')
plot(l,l*(l+1.)*EEs/2./np.pi*2.72e6**2,label='')
plot(l,l*(l+1.)*EEn/2./np.pi*2.72e6**2,label='noi (coadd)')
legend()

# %%
# BB
pl.plot_1dstyle(xmin=2,xmax=2048,ylog=True,ymin=1e-17,ymax=3e-16)
plot(l,l*BB0,label='sa')
plot(l,l*BB1,label='la')
plot(l,l*BB2,label='id')
plot(l,l*r.lcl[2,:],label='input')
legend()
