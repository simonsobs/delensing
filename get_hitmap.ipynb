# %%
import healpy as hp, numpy as np
import sys
sys.path.append('/global/homes/t/toshiyan/Work/Lib/actlib/PySM_public/')
sys.path.append('/global/homes/t/toshiyan/Work/Lib/actlib/so_pysm_models/')
sys.path.append('/global/homes/t/toshiyan/.local/cori/3.6-anaconda-4.4/lib/python3.7/site-packages/')
from mapsims import noise
import matplotlib.pyplot as plt

# %%
noise_sim = noise.SONoiseSimulator(4096)
# Out:
# /global/homes/t/toshiyan/.conda/envs/loc/lib/python3.7/site-packages/mapsims/SO_Noise_Calculator_Public_20180822.py:363: RuntimeWarning: overflow encountered in exp
#   N_ell_P_27  *= np.exp( ell*(ell+1)* SA_beams[0]**2. )
# /global/homes/t/toshiyan/.conda/envs/loc/lib/python3.7/site-packages/mapsims/SO_Noise_Calculator_Public_20180822.py:364: RuntimeWarning: overflow encountered in exp
#   N_ell_P_39  *= np.exp( ell*(ell+1)* SA_beams[1]**2. )
# /global/homes/t/toshiyan/.conda/envs/loc/lib/python3.7/site-packages/mapsims/SO_Noise_Calculator_Public_20180822.py:365: RuntimeWarning: overflow encountered in exp
#   N_ell_P_93  *= np.exp( ell*(ell+1)* SA_beams[2]**2. )

# %%
hp.mollview(noise_sim.hitmap['LA'])
plt.show()

# %%
hp.mollview(noise_sim.hitmap['SA'])
plt.show()
